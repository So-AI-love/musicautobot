# %% [markdown]
# <a href="https://colab.research.google.com/github/So-AI-love/musicautobot/blob/master/Pitch_analyser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install librosa matplotlib numpy scipy

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using librosa
def extract_pitch(y, sr):
    # Extract pitch and magnitude using librosa's piptrack
    pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr, fmin=75, fmax=1000)

    pitch = np.zeros(magnitudes.shape[1])
    for t in range(magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch[t] = pitches[index, t]

    # Smooth pitch contour with a Gaussian filter
    pitch = gaussian_filter1d(pitch, sigma=2)

    # Replace zeros with NaN for better plotting
    pitch[pitch == 0] = np.nan

    return pitch

# Function to plot the pitch contour
def plot_pitch_contour(pitch, sr):
    plt.figure(figsize=(14, 5))
    plt.plot(pitch, label='Pitch Contour')
    plt.xlabel('Time (frames)')
    plt.ylabel('Pitch (Hz)')
    plt.title('Pitch Contour Analysis')
    plt.legend()
    plt.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)
    pitch = extract_pitch(y, sr)
    plot_pitch_contour(pitch, sr)
# Out:
#      <input type="file" id="files-7bd92231-193f-48e4-9362-a0a05f44a62a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7bd92231-193f-48e4-9362-a0a05f44a62a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install librosa matplotlib numpy scipy music21

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from music21 import pitch
from collections import Counter

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using librosa
def extract_pitch(y, sr):
    pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr, fmin=75, fmax=1000)

    pitch_values = []
    for t in range(magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch_val = pitches[index, t]
        if pitch_val > 0:  # Consider only positive pitch values
            pitch_values.append(pitch_val)

    # Smooth pitch contour with a Gaussian filter
    pitch_values = gaussian_filter1d(pitch_values, sigma=2)

    return pitch_values

# Function to map pitch values to musical notes using music21
def map_pitch_to_notes(pitch_values):
    notes = []
    for p in pitch_values:
        if p > 0:
            note = pitch.Pitch()
            note.frequency = p
            notes.append(note.nameWithOctave)
    return notes

# Function to plot the pitch contour and display vocal range
def plot_pitch_and_vocal_range(pitch_values, notes):
    plt.figure(figsize=(14, 5))

    # Plot the pitch contour
    plt.subplot(2, 1, 1)
    plt.plot(pitch_values, label='Pitch Contour')
    plt.xlabel('Time (frames)')
    plt.ylabel('Pitch (Hz)')
    plt.title('Pitch Contour Analysis')
    plt.legend()

    # Calculate vocal range
    unique_notes = sorted(set(notes), key=lambda n: pitch.Pitch(n).frequency)
    print(f"Vocal Range: {unique_notes[0]} - {unique_notes[-1]}")
    print(f"Total unique notes in range: {len(unique_notes)}")

    # Plot the distribution of musical notes
    plt.subplot(2, 1, 2)
    note_counts = Counter(notes)
    plt.bar(note_counts.keys(), note_counts.values())
    plt.xlabel('Musical Notes')
    plt.ylabel('Frequency')
    plt.title('Distribution of Musical Notes')

    plt.tight_layout()
    plt.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)
    pitch_values = extract_pitch(y, sr)
    notes = map_pitch_to_notes(pitch_values)
    plot_pitch_and_vocal_range(pitch_values, notes)
# Out:
#      <input type="file" id="files-0561df75-fd19-42a4-bf83-648efdba0aa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0561df75-fd19-42a4-bf83-648efdba0aa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from music21 import stream, note, pitch

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using librosa
def extract_pitch(y, sr):
    pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr, fmin=75, fmax=1000)

    pitch_values = []
    for t in range(magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch_val = pitches[index, t]
        if pitch_val > 0:  # Consider only positive pitch values
            pitch_values.append(pitch_val)

    # Smooth pitch contour with a Gaussian filter
    pitch_values = gaussian_filter1d(pitch_values, sigma=2)

    return pitch_values

# Function to map pitch values to musical notes using music21
def map_pitch_to_notes(pitch_values):
    notes = []
    for p in pitch_values:
        if p > 0:
            n = pitch.Pitch()
            n.frequency = p
            notes.append(note.Note(n))
    return notes

# Function to create a music21 stream and display the notes
def create_music_score(notes):
    score = stream.Stream()
    for n in notes:
        score.append(n)

    # Display the score
    score.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)
    pitch_values = extract_pitch(y, sr)
    notes = map_pitch_to_notes(pitch_values)
    create_music_score(notes)
# Out:
#      <input type="file" id="files-d70e3a21-7789-46bf-b680-25191b82ec58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d70e3a21-7789-46bf-b680-25191b82ec58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from music21 import pitch
from collections import Counter

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using librosa
def extract_pitch(y, sr):
    pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr, fmin=75, fmax=1000)

    pitch_values = []
    for t in range(magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch_val = pitches[index, t]
        if pitch_val > 0:  # Consider only positive pitch values
            pitch_values.append(pitch_val)

    # Smooth pitch contour with a Gaussian filter
    pitch_values = gaussian_filter1d(pitch_values, sigma=2)

    return pitch_values

# Function to map pitch values to musical notes using music21
def map_pitch_to_notes(pitch_values):
    notes = []
    for p in pitch_values:
        if p > 0:
            note = pitch.Pitch()
            note.frequency = p
            notes.append(note.nameWithOctave)
    return notes

# Function to plot the pitch contour and display vocal range
def plot_pitch_and_vocal_range(pitch_values, notes):
    plt.figure(figsize=(14, 5))

    # Plot the pitch contour
    plt.subplot(2, 1, 1)
    plt.plot(pitch_values, label='Pitch Contour')
    plt.xlabel('Time (frames)')
    plt.ylabel('Pitch (Hz)')
    plt.title('Pitch Contour Analysis')
    plt.legend()

    # Calculate vocal range
    unique_notes = sorted(set(notes), key=lambda n: pitch.Pitch(n).frequency)
    print(f"Vocal Range: {unique_notes[0]} - {unique_notes[-1]}")
    print(f"Total unique notes in range: {len(unique_notes)}")

    # Plot the distribution of musical notes
    plt.subplot(2, 1, 2)
    note_counts = Counter(notes)
    plt.bar(note_counts.keys(), note_counts.values())
    plt.xlabel('Musical Notes')
    plt.ylabel('Frequency')
    plt.title('Distribution of Musical Notes')

    plt.tight_layout()
    plt.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)
    pitch_values = extract_pitch(y, sr)
    notes = map_pitch_to_notes(pitch_values)
    plot_pitch_and_vocal_range(pitch_values, notes)
# Out:
#      <input type="file" id="files-f86a18f7-1d27-41c6-b3d6-4671ebff6e21" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f86a18f7-1d27-41c6-b3d6-4671ebff6e21">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import necessary libraries
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from music21 import stream, note, pitch

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using librosa
def extract_pitch(y, sr):
    pitches, magnitudes = librosa.core.piptrack(y=y, sr=sr, fmin=75, fmax=1000)

    pitch_values = []
    for t in range(magnitudes.shape[1]):
        index = magnitudes[:, t].argmax()
        pitch_val = pitches[index, t]
        if pitch_val > 0:  # Consider only positive pitch values
            pitch_values.append(pitch_val)

    # Smooth pitch contour with a Gaussian filter
    pitch_values = gaussian_filter1d(pitch_values, sigma=2)

    return pitch_values

# Function to map pitch values to musical notes using music21
def map_pitch_to_notes(pitch_values):
    notes = []
    for p in pitch_values:
        if p > 0:
            n = pitch.Pitch()
            n.frequency = p
            notes.append(note.Note(n))
    return notes

# Function to create a music21 stream and display the notes
def create_music_score(notes):
    score = stream.Score()
    part = stream.Part()

    for n in notes:
        part.append(n)

    score.insert(0, part)

    # Display the score
    score.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)
    pitch_values = extract_pitch(y, sr)
    notes = map_pitch_to_notes(pitch_values)
    create_music_score(notes)
# Out:
#      <input type="file" id="files-0713a708-ebae-463a-8605-77e207b36e0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0713a708-ebae-463a-8605-77e207b36e0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install librosa matplotlib numpy scipy music21
# !pip install tensorflow tensorflow-addons  # For using Pitch Estimator
# !pip install transformers torchaudio  # For using Basic Pitch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.3.0
#     Uninstalling typeguard-4.3.0:
#       Successfully uninstalled typeguard-4.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# inflect 7.3.1 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# ...

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import gaussian_filter1d
from music21 import stream, note, pitch
import tensorflow as tf
import tensorflow_addons as tfa
from transformers import BasicPitchProcessor, BasicPitchModel

# Function to load an audio file
def load_audio_file(filepath):
    y, sr = librosa.load(filepath, sr=16000)  # Ensures a consistent sample rate
    return y, sr

# Function to extract pitch using Basic Pitch
def extract_pitch_basic_pitch(y, sr):
    processor = BasicPitchProcessor.from_pretrained("spotify/basic-pitch")
    model = BasicPitchModel.from_pretrained("spotify/basic-pitch")

    inputs = processor(y, return_tensors="pt", sampling_rate=sr)
    with torch.no_grad():
        outputs = model(**inputs)

    # Convert the output to MIDI format (or just extract pitches)
    midi_data = processor.decode(outputs.logits[0])
    return midi_data

# Function to extract pitch using TensorFlow SPICE model
def extract_pitch_tf_spice(y, sr):
    y = tf.convert_to_tensor(y, dtype=tf.float32)
    # SPICE model expects frames with a length of 2048
    frame_size = 2048
    frames = tf.signal.frame(y, frame_size, frame_size // 2)
    spice_model = tfa.layers.SPICE(frames_per_hop=512)

    pitch_values = spice_model(frames).numpy()

    # Filter out unvoiced frames
    pitch_values = pitch_values[pitch_values > 0]

    return pitch_values

# Function to map pitch values to musical notes using music21
def map_pitch_to_notes(pitch_values):
    notes = []
    for p in pitch_values:
        if p > 0:
            n = pitch.Pitch()
            n.frequency = p
            notes.append(note.Note(n))
    return notes

# Function to create a music21 stream and display the notes
def create_music_score(notes):
    score = stream.Stream()
    for n in notes:
        score.append(n)

    # Display the score
    score.show()

# Upload the audio file
from google.colab import files
uploaded = files.upload()

# Load and analyze the audio file
for filename in uploaded.keys():
    y, sr = load_audio_file(filename)

    # Choose method: Basic Pitch or TensorFlow SPICE
    method = "basic_pitch"  # Change to "tf_spice" for TensorFlow SPICE method

    if method == "basic_pitch":
        midi_data = extract_pitch_basic_pitch(y, sr)
        # Convert MIDI to notes (if needed)
        notes = map_pitch_to_notes(midi_data["midi"])
    else:
        pitch_values = extract_pitch_tf_spice(y, sr)
        notes = map_pitch_to_notes(pitch_values)

    create_music_score(notes)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.13.0 and strictly below 2.16.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.17.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# ...
